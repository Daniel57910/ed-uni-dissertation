# %%
OUT_FEATURE_COLUMNS = [
    "user_count",
    "project_count",
    "country_count", 
    
    "date_hour_sin", 
    "date_hour_cos",
    "date_minute_sin",
    "date_minute_cos",
    
    "session_30_count",
    "session_5_count",
    "cum_session_event_count",
    "delta_last_event",
    "cum_session_time",
    "expanding_click_average",
    
    "cum_platform_time",
    "cum_platform_events",
    "cum_projects",
    "average_event_time",
    
    "rolling_session_time",
    "rolling_session_events",
    "rolling_session_gap",
    "previous_session_time",
    "previous_session_events",
]

# %%
import pandas as pd

# %%
OUT_FEATURE_SEMANTICS = [
    "Classifications by User.",
    "Classifications by Project",
    "Classifications by Country.",
    
    "Hour of day sine transformed.",
    "Hour of day cosine transformed.",
    "Minute of hour sine transformed.",
    "Minute of hour cosine transformed.",
    
    "Cumulative 30 minute sessions.",
    "Cumulative 5 minute sessions.",
    "Cumulative events in session.",
    "Delta since last event.",
    "Cumulative time in session.",
    "Average delta within session.",
    
    "Cumulative time across platform.",
    "Cumulative events across platform.",
    "Cumulative projects participated in.",
    "Average delta across platform.",
    
    "Rolling average session time.",
    "Rolling average session events.",
    "Rolling delta between sessions.",
    "Previous session time.",
    "Previous session events."
]

# %%
df = pd.DataFrame({
    "Feature Name": OUT_FEATURE_COLUMNS,
    "Feature Description": OUT_FEATURE_SEMANTICS
})

# %%
df['Feature Name'] = df['Feature Name'].apply(lambda x: x.replace("_", " ").title())

# %%
df
# Out:
#                Feature Name                   Feature Description
# 0                User Count              Classifications by User.
# 1             Project Count            Classifications by Project
# 2             Country Count           Classifications by Country.
# 3             Date Hour Sin         Hour of day sine transformed.
# 4             Date Hour Cos       Hour of day cosine transformed.
# 5           Date Minute Sin      Minute of hour sine transformed.
# 6           Date Minute Cos    Minute of hour cosine transformed.
# 7          Session 30 Count        Cumulative 30 minute sessions.
# 8           Session 5 Count         Cumulative 5 minute sessions.
# 9   Cum Session Event Count         Cumulative events in session.
# 10         Delta Last Event               Delta since last event.
# 11         Cum Session Time           Cumulative time in session.
# 12  Expanding Click Average         Average delta within session.
# ...

# %%
print(df.to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
# Feature Name & Feature Description \\
# \midrule
# User Count & Classifications by User. \\
# Project Count & Classifications by Project \\
# Country Count & Classifications by Country. \\
# Date Hour Sin & Hour of day sine transformed. \\
# Date Hour Cos & Hour of day cosine transformed. \\
# Date Minute Sin & Minute of hour sine transformed. \\
# Date Minute Cos & Minute of hour cosine transformed. \\
# Session 30 Count & Cumulative 30 minute sessions. \\
# Session 5 Count & Cumulative 5 minute sessions. \\
# Cum Session Event Count & Cumulative events in session. \\
# Delta Last Event & Delta since last event. \\
# Cum Session Time & Cumulative time in session. \\
# Expanding Click Average & Average delta within session. \\
# Cum Platform Time & Cumulative time across platform. \\
# Cum Platform Events & Cumulative events across platform. \\
# Cum Projects & Cumulative projects participated in. \\
# ...

# %%
OUT_FEATURE_SEMANTICS
